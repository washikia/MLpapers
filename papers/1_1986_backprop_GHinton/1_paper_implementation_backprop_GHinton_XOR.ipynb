# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn.functional

# %%
# define input and output
x = torch.tensor([[0,0], [0,1], [1,0], [1,1]], dtype=torch.float32)
y = torch.tensor([[0], [1], [1], [0]], dtype=torch.float32)

# %%
# initiate weights and biases
W1 = torch.randn(2, 4, dtype=torch.float32, requires_grad=True)
b1 = torch.randn(4, dtype=torch.float32, requires_grad=True)
W2 = torch.randn(4, 1, dtype=torch.float32, requires_grad=True)
b2 = torch.randn(1, dtype=torch.float32, requires_grad=True)

# %%
# set the hyperparams
epochs = 10000
lr = 0.05
optimizer = torch.optim.SGD([W1, b1, W2, b2], lr=lr)

# %%
# training loop
for epoch in range(epochs):

  #forward pass
  hidden = torch.relu(x @ W1 + b1)
  output = torch.sigmoid(hidden @ W2 + b2)

  loss = torch.nn.functional.binary_cross_entropy(output, y)

  optimizer.zero_grad()
  loss.backward()
  optimizer.step()

  # with torch.no_grad():
  #   W1 -= lr * W1.grad
  #   b1 -= lr * b1.grad
  #   W2 -= lr * W2.grad
  #   b2 -= lr * b2.grad

  # W1.grad.zero_()
  # b1.grad.zero_()
  # W2.grad.zero_()
  # b2.grad.zero_()

  if epoch % 1000 == 0:
    print(f'Epoch: {epoch}, Loss: {loss.item()}')
# Out:
# Epoch: 0, Loss: 0.00391640467569232
# Epoch: 1000, Loss: 0.0034993046429008245
# Epoch: 2000, Loss: 0.003160591470077634
# Epoch: 3000, Loss: 0.0028787453193217516
# Epoch: 4000, Loss: 0.0026423512026667595
# Epoch: 5000, Loss: 0.0024404870346188545
# Epoch: 6000, Loss: 0.0022660272661596537
# Epoch: 7000, Loss: 0.0021146798972040415
# Epoch: 8000, Loss: 0.001981640001758933
# Epoch: 9000, Loss: 0.001863642712123692

# %%
with torch.no_grad():
  hidden = torch.relu(x @ W1 + b1)
  output = torch.sigmoid(hidden @ W2 + b2)
  print(output)
# Out:
# tensor([[7.2629e-04],
#         [9.9971e-01],
#         [9.9459e-01],
#         [5.9200e-04]])

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !cd drive

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !git clone https://github.com/washikia/MLpapers.git
# Out:
# Cloning into 'MLpapers'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 9 (delta 0), reused 6 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), 1.26 MiB | 3.70 MiB/s, done.

# %%
# !ls
# Out:
# drive  MLpapers  sample_data

# %%
# !cd MLpapers/

# %%
# !ls
# Out:
# 323533a0.pdf

# %%
# !mv ./drive/MyDrive/1_paper_implementation_backprop_GHinton_XOR.ipynb MLpapers/papers/1_1986_backprop_GHinton
# Out:
# mv: cannot stat './drive/MyDrive/1_paper_implementation_backprop_GHinton_XOR.ipynb': No such file or directory

# %%
# !cd ..

# %%
# !cd ..

# %%
# !ls
# Out:
# drive  MLpapers  sample_data

# %%
# %pwd
# Out:
# '/content/drive'

# %%
# %cd drive/MyDrive/home
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/home'
# /content
